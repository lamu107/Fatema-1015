# %% [markdown]
# <a href="https://colab.research.google.com/github/lamu107/Fatema-1015/blob/main/0432320005101015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
NormalValues = np.random.normal(8,2,3000)
plt.hist(NormalValues, bins=30, edgecolor='black')
plt.title('Histogram of Normal Distribution (mean=8, std=2)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Part 1: Data Generation
regular = np.random.uniform(2, 12, 3000)
busy = np.clip(np.random.normal(8, 2, 3000), 0, None)  # Replace negatives with 0

# Part 2: Visualization (Overlaid Histograms)
plt.hist(regular, bins=30, alpha=0.5, label='Regular Day', color='gray',edgecolor='black')
plt.hist(busy, bins=30, alpha=0.5, label='Busy Day', color='pink',edgecolor='black')
plt.xlabel('Wait Time (minutes)')
plt.ylabel('Frequency')
plt.title('Customer Wait Times')
plt.show()

# Part 3: Statistical Analysis
for name, data in [("Regular Day", regular), ("Busy Day", busy)]:
    print(f"{name}:")
    print(f"  Mean:   {np.mean(data):.2f}")
    print(f"  Median: {np.median(data):.2f}")
    print(f"  Std:    {np.std(data):.2f}")
    print(f"  Max:    {np.max(data):.2f}\n")
# Out:
# Regular Day:
#   Mean:   6.98
#   Median: 7.01
#   Std:    2.88
#   Max:    11.99
#
# Busy Day:
#   Mean:   7.95
#   Median: 7.95
#   Std:    2.00
#   Max:    14.23
